# %%
import pandas as pd

# Our starter dataset: GoT characters as "crime/threat profiles"
# Each row = one character. Each column = a trait our model can learn from.
data = {
    "character":      ["Cersei", "Ned", "Jon", "Tyrion", "Joffrey", "Daenerys", "Sansa", "Ramsay"],
    "betrayals":      [5, 0, 1, 2, 3, 1, 1, 6],          # times they betrayed someone
    "kills_ordered":  [8, 1, 4, 2, 5, 9, 0, 7],          # deaths they caused/ordered
    "allies":         [3, 6, 7, 5, 2, 6, 4, 1],          # how many strong allies
    "power_rank":     [9, 5, 6, 7, 8, 9, 4, 3],          # 1-10 influence in Westeros
    "threat":         ["High","Low","Medium","Medium","High","High","Low","High"]  # what we predict
}

df = pd.DataFrame(data)
print(df)
# Out:
#   character  betrayals  kills_ordered  allies  power_rank  threat
# 0    Cersei          5              8       3           9    High
# 1       Ned          0              1       6           5     Low
# 2       Jon          1              4       7           6  Medium
# 3    Tyrion          2              2       5           7  Medium
# 4   Joffrey          3              5       2           8    High
# 5  Daenerys          1              9       6           9    High
# 6     Sansa          1              0       4           4     Low
# 7    Ramsay          6              7       1           3    High

# %%
X = df[["betrayals", "kills_ordered", "allies", "power_rank"]]
y = df["threat"]
